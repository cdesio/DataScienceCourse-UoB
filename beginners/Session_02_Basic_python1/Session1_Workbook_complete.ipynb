# %% [markdown]
# ### Session 1 Exercise workbook

# %% [markdown]
# Let's do some exercises:
#
# 1) Print a sentence of your choice
# 2) Print your name
# 3) Create a variable and print its value
# 4) Calculate double and half
# 5) Multiply by another variable
# 6) Create list of numbers
# 7) Add number to list
# 8) Retrieve first, middle and last element

# %% [markdown]
# Exercise 1): Print a sentence of your choice

# %%
# insert code here

print("this is a sentence")
# Out:
# this is a sentence

# %% [markdown]
# Exercise 2): Print your name

# %%
# insert code here
my_name = "Mohammed"
print(my_name)
# Out:
# Mohammed

# %% [markdown]
# Exercise 3): Create a variable and print its value

# %%
# insert code here
var_1 = 8

print(var_1)
# Out:
# 8

# %% [markdown]
# Exercise 4): Calculate double and half

# %%
# insert code here
print("double:")
print(var_1 * 2)
print("half:")
print(var_1/2)
# Out:
# double:
# 16
# half:
# 4.0

# %% [markdown]
# Exercise 5): Multiply by another variable

# %%
# insert code here
var_2 = 3

print(var_1*var_2)
# Out:
# 24

# %% [markdown]
# Exercise 6): Create a list of numbers

# %%
# insert code here

my_list = [3, 4, 0.5, 1001]

# %%
print(my_list)
# Out:
# [3, 4, 0.5, 1001]

# %% [markdown]
# Exercise 7): add number to the list

# %%
# insert code here

my_list.append(-2)

# %%
print(my_list)
# Out:
# [3, 4, 0.5, 1001, -2]

# %% [markdown]
# Exercise 8): Retrieve first, middle and last element

# %%
# insert code here


print("first item: ", my_list[0])
print("middle item: ", my_list[2])
print("last item - mode 1: ", my_list[4])
print("last item - mode 2: ", my_list[-1])
# Out:
# first item:  3
# middle item:  0.5
# last item - mode 1:  -2
# last item - mode 2:  -2

# %%
length = len(my_list)

# %%
middle_index = int(length/2)

# %%
my_list[middle_index]
# Out:
# 0.5

# %%
my_list.insert(0, 5)

# %%
my_list
# Out:
# [5, 3, 4, 0.5, 1001, -2]
