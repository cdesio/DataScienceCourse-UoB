# %%
print("This is a test")
# Out:
# This is a test

# %%
print("goodbye")
# Out:
# goodbye

# %%
pwd
# Out:
# '/Users/yw18581/Library/CloudStorage/OneDrive-UniversityofBristol/DST-25/Data_science_Teaching/Material/Session_01_introduction'
